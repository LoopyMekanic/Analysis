# %% [markdown]
# <a href="https://colab.research.google.com/github/LoopyMekanic/Analysis/blob/Trying-to-learn/Numpy_4_Copy_vs_View.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
np1 = np.array([1,2,3,4,5])
# Create a view (Linked to original array)
np2 = np1.view()

# %%
# Change our original
np1[0] =41

# %%
# Print these out
print(f'Original np1: {np1}')
print(f'Original/View np1: {np2}')
# Out:
# Original np1: [41  2  3  4  5]
# Original/View np1: [41  2  3  4  5]

# %%
# Create a Copy that is NOT linked to the original
np3 = np1.copy()
# Alternative Method: np3 = np.array(np1)

# %%
# Print these out
print(f'Original np1: {np1}')
print(f'Original/Copy np3: {np3}')
# Out:
# Original np1: [41  2  3  4  5]
# Original/Copy np3: [41  2  3  4  5]

# %%
# Change our np1 again
np1[0] = 41

# %%
# Print these out
print(f'Changed np1: {np1}')
print(f'Original/Copy np3: {np3}')
# Out:
# Changed np1: [1 2 3 4 5]
# Original/Copy np3: [41  2  3  4  5]
